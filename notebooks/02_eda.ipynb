# %% [markdown]
# # 📊 Phase 2: Exploratory Data Analysis (EDA)
#
# In this notebook, you will:
# 1. Explore the distribution of numerical and categorical features
# 2. Create visualizations using Matplotlib and Seaborn
# 3. Analyze churn patterns across different customer segments
# 4. Generate a correlation heatmap
# 5. Document your key findings and insights
#
# ---

# %% [markdown]
# ## 2.1 — Import Libraries & Load Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Set plot style
sns.set_theme(style='whitegrid', palette='Set2')
plt.rcParams['figure.figsize'] = (10, 6)
plt.rcParams['font.size'] = 12

# %matplotlib inline

print("Libraries imported successfully!")

# %%
# Load the data saved from Phase 1
df = pd.read_csv('../data/processed_data.csv')
print(f"Dataset shape: {df.shape}")
df.head()

# %% [markdown]
# ## 2.2 — Target Variable Analysis
#
# Let's start by understanding the target variable: **Churn**

# %%
# TODO: Create a count plot showing the distribution of Churn (Yes vs No)
# Hint: Use sns.countplot()
# Also calculate and print the churn rate as a percentage

# Your code here:

# %% [markdown]
# **📝 Your Insight:** *(Write your observation about the churn distribution here)*
#
# - Is the dataset balanced or imbalanced?
# - What percentage of customers churned?

# %% [markdown]
# ## 2.3 — Numerical Features Distribution
#
# Analyze the distribution of numerical features: `tenure`, `monthly_charges`, `total_charges`

# %%
# TODO: Create histograms for numerical features
# Hint: Use plt.subplot() to create a 1x3 grid of histograms
# Color them by churn status using the 'hue' parameter in seaborn

numerical_features = ['tenure', 'monthly_charges', 'total_charges']

fig, axes = plt.subplots(1, 3, figsize=(18, 5))

for i, feature in enumerate(numerical_features):
    # TODO: Create a histogram for each feature, colored by churn
    # Hint: sns.histplot(data=df, x=feature, hue='churn', ax=axes[i], kde=True)
    pass

plt.tight_layout()
plt.show()

# %%
# TODO: Create box plots for numerical features grouped by churn
# Hint: Use sns.boxplot() with x='churn' and y=feature

fig, axes = plt.subplots(1, 3, figsize=(18, 5))

for i, feature in enumerate(numerical_features):
    # TODO: Create a box plot for each feature
    pass

plt.tight_layout()
plt.show()

# %% [markdown]
# **📝 Your Insight:** *(Write your observations about numerical features here)*
#
# - How does tenure differ between churned and non-churned customers?
# - What patterns do you see in monthly charges?

# %% [markdown]
# ## 2.4 — Categorical Features Analysis
#
# Analyze how churn varies across categorical features.

# %%
# TODO: Create count plots for key categorical features, split by churn
# Analyze at least these features: contract, internet_service, payment_method, gender

categorical_features = ['contract', 'internet_service', 'payment_method', 
                        'gender', 'partner', 'dependents']

fig, axes = plt.subplots(2, 3, figsize=(20, 12))
axes = axes.flatten()

for i, feature in enumerate(categorical_features):
    # TODO: Create a count plot for each categorical feature
    # Hint: sns.countplot(data=df, x=feature, hue='churn', ax=axes[i])
    pass

plt.tight_layout()
plt.show()

# %%
# TODO: Calculate churn rate by contract type
# Hint: Use groupby and calculate the percentage of 'Yes' churn in each group

# Your code here:

# %% [markdown]
# **📝 Your Insight:** *(Write your observations about categorical features here)*
#
# - Which contract type has the highest churn rate? Why do you think that is?
# - Does internet service type affect churn?

# %% [markdown]
# ## 2.5 — Correlation Analysis

# %%
# TODO: Create a correlation heatmap for numerical features
# Steps:
#   1. Select only numerical columns
#   2. If 'churn' is categorical, convert it to numeric (Yes=1, No=0)
#   3. Calculate the correlation matrix using .corr()
#   4. Plot using sns.heatmap() with annotations

# Your code here:

# %% [markdown]
# **📝 Your Insight:** *(Write your observations about correlations here)*
#
# - Which features are most correlated with churn?
# - Are there any strong correlations between features (multicollinearity)?

# %% [markdown]
# ## 2.6 — Service Add-on Analysis
#
# Analyze how service add-ons (security, backup, tech support, etc.) affect churn.

# %%
# TODO: Analyze churn rate for each service add-on
# Services to analyze: online_security, online_backup, device_protection, tech_support
# For each service, calculate the churn rate when the service is 'Yes' vs 'No'

service_features = ['online_security', 'online_backup', 
                    'device_protection', 'tech_support']

# Your code here:

# %% [markdown]
# **📝 Your Insight:** *(Write your observations about service add-ons here)*
#
# - Do customers with service add-ons churn less?
# - Which add-on has the biggest impact on reducing churn?

# %% [markdown]
# ## 2.7 — Summary of Key Findings
#
# ### TODO: Write a summary of your EDA findings
#
# Answer these questions in your own words:
#
# 1. **What is the overall churn rate?**
#    - *Your answer here*
#
# 2. **What are the top 3 factors most associated with churn?**
#    - *Your answer here*
#
# 3. **What customer segments are most at risk?**
#    - *Your answer here*
#
# 4. **What business recommendations would you make based on the EDA?**
#    - *Your answer here*

# %% [markdown]
# ---
# ## ✅ Phase 2 Complete!
#
# **What you accomplished:**
# - Explored the distribution of all features
# - Created visualizations to understand churn patterns
# - Identified key factors associated with customer churn
# - Documented your insights and observations
#
# **Next:** Move on to `03_feature_engineering.ipynb` for data preprocessing.
