# %% [markdown]
# # 🤖 Phase 4: Machine Learning Models
#
# In this notebook, you will:
# 1. Train a Logistic Regression baseline model
# 2. Train a Random Forest classifier
# 3. Train an XGBoost classifier
# 4. Perform hyperparameter tuning with GridSearchCV
# 5. Analyze feature importance
#
# ---

# %% [markdown]
# ## 4.1 — Import Libraries & Load Processed Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pickle
import sys, os

from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.model_selection import GridSearchCV, cross_val_score
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score, f1_score,
    roc_auc_score, classification_report
)

sys.path.append(os.path.join(os.getcwd(), '..'))
from src.evaluation import (print_metrics, plot_confusion_matrix,
                             plot_feature_importance)

print("Libraries imported successfully!")

# %%
# Load the processed data from Phase 3
with open('../data/processed_splits.pkl', 'rb') as f:
    data = pickle.load(f)

X_train = data['X_train']
X_test = data['X_test']
y_train = data['y_train']
y_test = data['y_test']

print(f"Training set: {X_train.shape}")
print(f"Test set: {X_test.shape}")

# %% [markdown]
# ## 4.2 — Model 1: Logistic Regression (Baseline)
#
# Start with a simple logistic regression as your baseline model.

# %%
# TODO: Train a Logistic Regression model
# Hint:
# lr_model = LogisticRegression(max_iter=1000, random_state=42)
# lr_model.fit(X_train, y_train)
# lr_pred = lr_model.predict(X_test)

# Your code here:

# %%
# TODO: Evaluate the Logistic Regression model
# Use print_metrics() and plot_confusion_matrix() from src.evaluation

# Hint:
# lr_metrics = print_metrics(y_test, lr_pred, model_name='Logistic Regression')
# plot_confusion_matrix(y_test, lr_pred, model_name='Logistic Regression')

# Your code here:

# %% [markdown]
# **📝 Your Insight:** *(How did the baseline Logistic Regression perform? What do accuracy, precision, and recall tell you?)*

# %% [markdown]
# ## 4.3 — Model 2: Random Forest

# %%
# TODO: Train a Random Forest classifier
# Hint:
# rf_model = RandomForestClassifier(n_estimators=100, random_state=42)
# rf_model.fit(X_train, y_train)
# rf_pred = rf_model.predict(X_test)

# Your code here:

# %%
# TODO: Evaluate the Random Forest model

# Your code here:

# %%
# TODO: Plot feature importance for Random Forest
# Hint: plot_feature_importance(rf_model, X_train.columns, top_n=15)

# Your code here:

# %% [markdown]
# **📝 Your Insight:** *(How does Random Forest compare to Logistic Regression? What are the most important features?)*

# %% [markdown]
# ## 4.4 — Model 3: XGBoost

# %%
# TODO: Train an XGBoost classifier
# Hint:
# xgb_model = XGBClassifier(
#     n_estimators=100, 
#     learning_rate=0.1,
#     max_depth=5,
#     random_state=42,
#     eval_metric='logloss'
# )
# xgb_model.fit(X_train, y_train)
# xgb_pred = xgb_model.predict(X_test)

# Your code here:

# %%
# TODO: Evaluate the XGBoost model

# Your code here:

# %%
# TODO: Plot feature importance for XGBoost

# Your code here:

# %% [markdown]
# ## 4.5 — Hyperparameter Tuning with GridSearchCV
#
# Tune the best-performing model using GridSearchCV.

# %%
# TODO: Perform hyperparameter tuning on your best model
#
# Example for Random Forest:
# param_grid = {
#     'n_estimators': [100, 200, 300],
#     'max_depth': [5, 10, 15, None],
#     'min_samples_split': [2, 5, 10],
#     'min_samples_leaf': [1, 2, 4]
# }
#
# grid_search = GridSearchCV(
#     RandomForestClassifier(random_state=42),
#     param_grid,
#     cv=5,
#     scoring='f1',
#     n_jobs=-1,
#     verbose=1
# )
# grid_search.fit(X_train, y_train)

# Your code here:

# %%
# TODO: Print the best parameters and evaluate the tuned model
# print(f"Best parameters: {grid_search.best_params_}")
# print(f"Best CV score: {grid_search.best_score_:.4f}")

# best_model = grid_search.best_estimator_
# best_pred = best_model.predict(X_test)
# print_metrics(y_test, best_pred, model_name='Tuned Model')

# Your code here:

# %% [markdown]
# ## 4.6 — Save Models & Results

# %%
# Save the trained models and their metrics for Phase 6
ml_results = {
    'models': {
        # 'Logistic Regression': lr_model,
        # 'Random Forest': rf_model,
        # 'XGBoost': xgb_model,
    },
    'metrics': {
        # 'Logistic Regression': lr_metrics,
        # 'Random Forest': rf_metrics,
        # 'XGBoost': xgb_metrics,
    }
}

with open('../data/ml_results.pkl', 'wb') as f:
    pickle.dump(ml_results, f)

print("ML results saved to data/ml_results.pkl")

# %% [markdown]
# ---
# ## ✅ Phase 4 Complete!
#
# **What you accomplished:**
# - Trained 3 different ML models
# - Evaluated each model with classification metrics
# - Performed hyperparameter tuning
# - Analyzed feature importance
#
# **Next:** Move on to `05_deep_learning.ipynb` to build a neural network.
