# %% [markdown]
# # 🧠 Phase 5: Deep Learning Model
#
# In this notebook, you will:
# 1. Build a feedforward neural network using TensorFlow/Keras
# 2. Choose the architecture (layers, activations, dropout)
# 3. Train with early stopping and validation monitoring
# 4. Plot training/validation loss and accuracy curves
# 5. Evaluate the model on the test set
#
# ---

# %% [markdown]
# ## 5.1 — Import Libraries & Load Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pickle
import sys, os

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, callbacks

from sklearn.metrics import classification_report, accuracy_score

sys.path.append(os.path.join(os.getcwd(), '..'))
from src.evaluation import print_metrics, plot_confusion_matrix

print(f"TensorFlow version: {tf.__version__}")
print("Libraries imported successfully!")

# %%
# Load the processed data from Phase 3
with open('../data/processed_splits.pkl', 'rb') as f:
    data = pickle.load(f)

X_train = data['X_train']
X_test = data['X_test']
y_train = data['y_train']
y_test = data['y_test']

# Convert to numpy arrays for Keras
X_train_np = X_train.values if hasattr(X_train, 'values') else X_train
X_test_np = X_test.values if hasattr(X_test, 'values') else X_test
y_train_np = y_train.values if hasattr(y_train, 'values') else y_train
y_test_np = y_test.values if hasattr(y_test, 'values') else y_test

input_dim = X_train_np.shape[1]
print(f"Input dimensions: {input_dim} features")
print(f"Training samples: {X_train_np.shape[0]}")
print(f"Test samples: {X_test_np.shape[0]}")

# %% [markdown]
# ## 5.2 — Build the Neural Network
#
# ### TODO: Design a feedforward neural network
#
# Your network should have:
# - An input layer matching the number of features
# - 2-3 hidden layers with decreasing neurons (e.g., 64 → 32 → 16)
# - ReLU activation for hidden layers
# - Dropout layers for regularization (0.2-0.3)
# - A sigmoid output layer (binary classification)

# %%
# TODO: Build the neural network model
#
# Hint:
# model = keras.Sequential([
#     layers.Dense(64, activation='relu', input_shape=(input_dim,)),
#     layers.Dropout(0.3),
#     layers.Dense(32, activation='relu'),
#     layers.Dropout(0.2),
#     layers.Dense(16, activation='relu'),
#     layers.Dense(1, activation='sigmoid')  # Binary output
# ])

# Your code here:

# %%
# TODO: Compile the model
#
# Hint:
# model.compile(
#     optimizer='adam',
#     loss='binary_crossentropy',
#     metrics=['accuracy']
# )

# Your code here:

# %%
# View the model summary
# model.summary()

# %% [markdown]
# ## 5.3 — Train the Model
#
# Use early stopping to prevent overfitting.

# %%
# TODO: Set up early stopping callback
#
# Hint:
# early_stop = callbacks.EarlyStopping(
#     monitor='val_loss',
#     patience=10,
#     restore_best_weights=True
# )

# Your code here:

# %%
# TODO: Train the model
#
# Hint:
# history = model.fit(
#     X_train_np, y_train_np,
#     epochs=100,
#     batch_size=32,
#     validation_split=0.2,
#     callbacks=[early_stop],
#     verbose=1
# )

# Your code here:

# %% [markdown]
# ## 5.4 — Plot Training Curves

# %%
# TODO: Plot training and validation loss curves
#
# Hint:
# fig, axes = plt.subplots(1, 2, figsize=(14, 5))
#
# # Loss curve
# axes[0].plot(history.history['loss'], label='Training Loss')
# axes[0].plot(history.history['val_loss'], label='Validation Loss')
# axes[0].set_title('Loss Curves')
# axes[0].set_xlabel('Epoch')
# axes[0].set_ylabel('Loss')
# axes[0].legend()
#
# # Accuracy curve
# axes[1].plot(history.history['accuracy'], label='Training Accuracy')
# axes[1].plot(history.history['val_accuracy'], label='Validation Accuracy')
# axes[1].set_title('Accuracy Curves')
# axes[1].set_xlabel('Epoch')
# axes[1].set_ylabel('Accuracy')
# axes[1].legend()
#
# plt.tight_layout()
# plt.show()

# Your code here:

# %% [markdown]
# **📝 Your Insight:** *(Analyze the training curves)*
#
# - Is the model overfitting or underfitting?
# - At what epoch did the model converge?
# - Is there a significant gap between training and validation performance?

# %% [markdown]
# ## 5.5 — Evaluate on Test Set

# %%
# TODO: Make predictions on the test set
#
# Hint:
# y_pred_prob = model.predict(X_test_np)
# y_pred = (y_pred_prob > 0.5).astype(int).flatten()

# Your code here:

# %%
# TODO: Evaluate the deep learning model
# Use print_metrics() and plot_confusion_matrix()

# dl_metrics = print_metrics(y_test_np, y_pred, model_name='Neural Network')
# plot_confusion_matrix(y_test_np, y_pred, model_name='Neural Network')

# Your code here:

# %% [markdown]
# ## 5.6 — Save the Model & Results

# %%
# Save the trained neural network model
# model.save('../models/neural_network.h5')
# print("Model saved to models/neural_network.h5")

# Save the metrics for Phase 6
# dl_results = {
#     'metrics': dl_metrics,
#     'y_pred': y_pred,
#     'y_pred_prob': y_pred_prob
# }
# with open('../data/dl_results.pkl', 'wb') as f:
#     pickle.dump(dl_results, f)
# print("DL results saved to data/dl_results.pkl")

# %% [markdown]
# ---
# ## ✅ Phase 5 Complete!
#
# **What you accomplished:**
# - Built a feedforward neural network with TensorFlow/Keras
# - Trained with early stopping to prevent overfitting
# - Visualized training and validation curves
# - Evaluated the model on the test set
#
# **Next:** Move on to `06_evaluation.ipynb` to compare all models.
